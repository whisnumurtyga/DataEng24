# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "http://books.toscrape.com/"
req = requests.get(url)
print(req)
print('--------------')
print(req.text)
# Out:
# <Response [200]>
# --------------
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->
#     <head>
#         <title>
#     All products | Books to Scrape - Sandbox
# </title>
#
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#         <meta name="created" content="24th Jun 2016 09:29" />
#         <meta name="description" content="" />
#         <meta name="viewport" content="width=device-width" />
#         <meta name="robots" content="NOARCHIVE,NOCACHE" />
#
#         <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#         <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# ...

# %%
soup = BeautifulSoup(req.text,"html.parser")
print(soup.title)
# Out:
# <title>
#     All products | Books to Scrape - Sandbox
# </title>

# %%
for link in soup.find_all('a'):
    print(link.get("href"))
# Out:
# index.html
# index.html
# catalogue/category/books_1/index.html
# catalogue/category/books/travel_2/index.html
# catalogue/category/books/mystery_3/index.html
# catalogue/category/books/historical-fiction_4/index.html
# catalogue/category/books/sequential-art_5/index.html
# catalogue/category/books/classics_6/index.html
# catalogue/category/books/philosophy_7/index.html
# catalogue/category/books/romance_8/index.html
# catalogue/category/books/womens-fiction_9/index.html
# catalogue/category/books/fiction_10/index.html
# catalogue/category/books/childrens_11/index.html
# catalogue/category/books/religion_12/index.html
# catalogue/category/books/nonfiction_13/index.html
# catalogue/category/books/music_14/index.html
# catalogue/category/books/default_15/index.html
# catalogue/category/books/science-fiction_16/index.html
# catalogue/category/books/sports-and-games_17/index.html
# catalogue/category/books/add-a-comment_18/index.html
# catalogue/category/books/fantasy_19/index.html
# ...

# %%
Judul = soup.find_all(class_ = "side_categories")
for judul in Judul:
    print(judul.text)
# Out:
#
#                                 Books
#
#
#
#
#
#
#                                 Travel
#
#
#
#
#
#
#                                 Mystery
#
#
#
#
#
#
#                                 Historical Fiction
#
#
#
#
#
#
#                                 Sequential Art
#
#
#
#
#
#
#                                 Classics
#
#
#
#
#
#
#                                 Philosophy
#
#
#
#
#
#
#                                 Romance
#
#
#
#
#
#
#                                 Womens Fiction
#
#
#
#
#
#
#                                 Fiction
#
#
#
#
#
#
#                                 Childrens
#
#
#
#
#
#
#                                 Religion
#
#
#
#
#
#
#                                 Nonfiction
#
#
#
#
#
#
#                                 Music
#
#
#
#
#
#
#                                 Default
#
#
#
#
#
#
#                                 Science Fiction
#
#
#
#
#
#
#                                 Sports and Games
#
#
#
#
#
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
books = []


url = "http://books.toscrape.com/catalogue/category/books/classics_6/index.html"
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')
ol = soup.find('ol')
articles = ol.find_all('article', class_='product_pod')
for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    starTag = article.find('p')
    star = starTag['class'][1]
    price = article.find('p', class_='price_color').text
    price = float(price[1:])
    books.append([title, star, price])
    

df = pd.DataFrame(books, columns=['Judul', 'Rating', 'Harga'])
df
# Out:
#                                                 Judul Rating  Harga
# 0                                   The Secret Garden   Four  15.08
# 1                                   The Metamorphosis    One  28.58
# 2                              The Pilgrim's Progress    Two  50.26
# 3   The Hound of the Baskervilles (Sherlock Holmes...    Two  14.82
# 4                      Little Women (Little Women #1)   Four  28.07
# 5                                  Gone with the Wind  Three  32.49
# 6                                             Candide  Three  58.63
# 7                                         Animal Farm  Three  57.22
# 8                                   Wuthering Heights  Three  17.73
# 9                          The Picture of Dorian Gray    Two  29.70
# 10  The Complete Stories and Poems (The Works of E...   Four  26.78
# 11                                            Beowulf    Two  38.35
# 12                           And Then There Were None    Two  35.01
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
books = []


url = "http://books.toscrape.com/catalogue/category/books/travel_2/index.html"
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')
ol = soup.find('ol')
articles = ol.find_all('article', class_='product_pod')
for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    starTag = article.find('p')
    star = starTag['class'][1]
    price = article.find('p', class_='price_color').text
    price = float(price[1:])
    books.append([title, star, price])
    

df1 = pd.DataFrame(books, columns=['Judul', 'Rating', 'Harga'])
df1
# Out:
#                                                 Judul Rating  Harga
# 0                             It's Only the Himalayas    Two  45.17
# 1   Full Moon over Noah’s Ark: An Odyssey to Mount...   Four  49.43
# 2   See America: A Celebration of Our National Par...  Three  48.87
# 3   Vagabonding: An Uncommon Guide to the Art of L...    Two  36.94
# 4                                Under the Tuscan Sun  Three  37.33
# 5                                  A Summer In Europe    Two  44.34
# 6                            The Great Railway Bazaar    One  30.54
# 7                    A Year in Provence (Provence #1)   Four  56.88
# 8   The Road to Little Dribbling: Adventures of an...    One  23.21
# 9           Neither Here nor There: Travels in Europe  Three  38.95
# 10                 1,000 Places to See Before You Die   Five  26.08

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
books = []


url = "http://books.toscrape.com/catalogue/category/books/horror_31/index.html"
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')
ol = soup.find('ol')
articles = ol.find_all('article', class_='product_pod')
for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    starTag = article.find('p')
    star = starTag['class'][1]
    price = article.find('p', class_='price_color').text
    price = float(price[1:])
    books.append([title, star, price])
    

df2 = pd.DataFrame(books, columns=['Judul', 'Rating', 'Harga'])
df2
# Out:
#                                                Judul Rating  Harga
# 0                                           Security    Two  39.25
# 1                                    Follow You Home    One  21.36
# 2                                          The Loney    One  23.40
# 3                                       Pet Sematary  Three  10.56
# 4                      Doctor Sleep (The Shining #2)    Two  40.12
# 5                   Psycho: Sanitarium (Psycho #1.5)   Five  36.97
# 6   Can You Keep a Secret? (Fear Street Relaunch #4)    One  48.64
# 7                    Red Dragon (Hannibal Lecter #1)  Three  23.37
# 8                                Dracula the Un-Dead   Five  35.63
# 9                    Night Shift (Night Shift #1-20)   Four  12.75
# 10                                    Needful Things   Four  47.51
# 11                                            Misery    Two  34.79
# 12                                                It  Three  25.01
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
books = []


url = "http://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html"
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')
ol = soup.find('ol')
articles = ol.find_all('article', class_='product_pod')
for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    starTag = article.find('p')
    star = starTag['class'][1]
    price = article.find('p', class_='price_color').text
    price = float(price[1:])
    books.append([title, star, price])
    

df3 = pd.DataFrame(books, columns=['Judul', 'Rating', 'Harga'])
df3
# Out:
#                                                 Judul Rating  Harga
# 0   Mesaerion: The Best Science Fiction Stories 18...    One  37.59
# 1                                                Join   Five  35.67
# 2   William Shakespeare's Star Wars: Verily, A New...   Four  43.30
# 3                                         The Project    One  10.65
# 4                                     Soft Apocalypse    Two  26.12
# 5                   Sleeping Giants (Themis Files #1)    One  48.74
# 6                                               Arena   Four  21.36
# 7      Foundation (Foundation (Publication Order) #1)    One  32.42
# 8   The Restaurant at the End of the Universe (Hit...    One  10.92
# 9                                    Ready Player One   Four  19.07
# 10  Life, the Universe and Everything (Hitchhiker'...    Two  33.26
# 11                                     Dune (Dune #1)    One  54.86
# 12  Do Androids Dream of Electric Sheep? (Blade Ru...    One  51.48
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
books = []


url = "http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html"
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')
ol = soup.find('ol')
articles = ol.find_all('article', class_='product_pod')
for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    starTag = article.find('p')
    star = starTag['class'][1]
    price = article.find('p', class_='price_color').text
    price = float(price[1:])
    books.append([title, star, price])
    

df4 = pd.DataFrame(books, columns=['Judul', 'Rating', 'Harga'])
df4
# Out:
#                                                 Judul Rating  Harga
# 0   I Had a Nice Time And Other Lies...: How to fi...   Four  57.36
# 1                         Will You Won't You Want Me?  Three  13.86
# 2                                      Keep Me Posted   Four  20.46
# 3                              Grey (Fifty Shades #4)   Four  48.49
# 4                                           Meternity  Three  43.58
# 5                                          Some Women   Five  13.73
# 6            Shopaholic Ties the Knot (Shopaholic #3)   Five  48.39
# 7                              Can You Keep a Secret?    One  21.94
# 8                                       Twenties Girl    Two  42.80
# 9                              The Undomestic Goddess   Four  45.75
# 10                       The Nanny Diaries (Nanny #1)   Five  52.53
# 11   The Devil Wears Prada (The Devil Wears Prada #1)    One  44.29
# 12             Something Borrowed (Darcy & Rachel #1)   Five  48.96
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
books = []


url = "http://books.toscrape.com/catalogue/category/books/politics_48/index.html"
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')
ol = soup.find('ol')
articles = ol.find_all('article', class_='product_pod')
for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    starTag = article.find('p')
    star = starTag['class'][1]
    price = article.find('p', class_='price_color').text
    price = float(price[1:])
    books.append([title, star, price])
    

df5 = pd.DataFrame(books, columns=['Judul', 'Rating', 'Harga'])
df5
# Out:
#                                                Judul Rating  Harga
# 0                       Libertarianism for Beginners    Two  51.33
# 1  Why the Right Went Wrong: Conservatism--From G...   Four  52.65
# 2  Equal Is Unfair: America's Misguided Fight Aga...    One  56.86

# %%
books = []

for i in range(1,3):
    url = f"http://books.toscrape.com/catalogue/category/books/fantasy_19/page-{i}.html"
    response = requests.get(url)
    response = response.content
    soup = BeautifulSoup(response, 'html.parser')
    ol = soup.find('ol')
    articles = ol.find_all('article', class_='product_pod')
for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    starTag = article.find('p')
    star = starTag['class'][1]
    price = article.find('p', class_='price_color').text
    price = float(price[1:])
    books.append([title, star, price])
    

df6 = pd.DataFrame(books, columns=['Judul', 'Rating', 'Harga'])
df6
# Out:
#                                                 Judul Rating  Harga
# 0    Every Heart a Doorway (Every Heart A Doorway #1)   Five  12.16
# 1         A Gathering of Shadows (Shades of Magic #2)   Four  44.81
# 2                 The Raven Boys (The Raven Cycle #1)   Four  57.74
# 3        The False Prince (The Ascendance Trilogy #1)   Five  56.00
# 4                              Tell the Wind and Fire  Three  45.51
# 5       A Feast for Crows (A Song of Ice and Fire #4)   Four  17.21
# 6                         The Demonists (Demonist #1)    Two  52.11
# 7            The Beast (Black Dagger Brotherhood #14)   Five  46.08
# 8               Paper and Fire (The Great Library #2)   Five  49.45
# 9   Harry Potter and the Order of the Phoenix (Har...   Four  31.63
# 10  Harry Potter and the Half-Blood Prince (Harry ...   Five  48.75
# 11  Harry Potter and the Chamber of Secrets (Harry...    One  14.74
# 12  The Rose & the Dagger (The Wrath and the Dawn #2)   Four  58.64
# ...

# %%
books = []


url = "http://books.toscrape.com/catalogue/category/books/religion_12/index.html"
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')
ol = soup.find('ol')
articles = ol.find_all('article', class_='product_pod')
for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    starTag = article.find('p')
    star = starTag['class'][1]
    price = article.find('p', class_='price_color').text
    price = float(price[1:])
    books.append([title, star, price])
    

df7 = pd.DataFrame(books, columns=['Judul', 'Rating', 'Harga'])
df7
# Out:
#                                                Judul Rating  Harga
# 0  Don't Be a Jerk: And Other Practical Advice fr...    Two  37.97
# 1  You Are What You Love: The Spiritual Power of ...   Four  21.87
# 2  God: The Most Unpleasant Character in All Fiction   Five  30.03
# 3                                 The Book of Mormon  Three  24.57
# 4  A History of God: The 4,000-Year Quest of Juda...    One  27.62
# 5                                  The Bhagavad Gita  Three  57.49
# 6  Choosing Our Religion: The Spiritual Lives of ...   Four  28.42

# %%
books = []


url = "http://books.toscrape.com/catalogue/category/books/sports-and-games_17/index.html"
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')
ol = soup.find('ol')
articles = ol.find_all('article', class_='product_pod')
for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    starTag = article.find('p')
    star = starTag['class'][1]
    price = article.find('p', class_='price_color').text
    price = float(price[1:])
    books.append([title, star, price])
    

df8 = pd.DataFrame(books, columns=['Judul', 'Rating', 'Harga'])
df8
# Out:
#                                                Judul Rating  Harga
# 0  The Book of Basketball: The NBA According to T...   Five  44.84
# 1   Friday Night Lights: A Town, a Team, and a Dream  Three  51.22
# 2                     Sugar Rush (Offensive Line #2)    One  24.42
# 3           Settling the Score (The Summer Games #1)    Two  44.91
# 4                             Icing (Aces Hockey #2)   Four  40.44

# %%
books = []

for i in range(1,2):
    url = f"http://books.toscrape.com/catalogue/category/books/romance_8/page-{i}.html"
    response = requests.get(url)
    response = response.content
    soup = BeautifulSoup(response, 'html.parser')
    ol = soup.find('ol')
    articles = ol.find_all('article', class_='product_pod')
for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    starTag = article.find('p')
    star = starTag['class'][1]
    price = article.find('p', class_='price_color').text
    price = float(price[1:])
    books.append([title, star, price])
    

df9 = pd.DataFrame(books, columns=['Judul', 'Rating', 'Harga'])
df9
# Out:
#                                                Judul Rating  Harga
# 0                         Chase Me (Paris Nights #2)   Five  25.27
# 1                                         Black Dust   Five  34.53
# 2      Her Backup Boyfriend (The Sorensen Family #1)    One  33.97
# 3                 First and First (Five Boroughs #3)   Four  15.97
# 4              Fifty Shades Darker (Fifty Shades #2)    One  21.96
# 5                                  The Wedding Dress    One  24.12
# 6                   Suddenly in Love (Lake Haven #1)    Two  55.99
# 7                           Something More Than This   Four  16.24
# 8                  Doing It Over (Most Likely To #1)  Three  35.61
# 9                The Wedding Pact (The O'Malleys #2)  Three  32.61
# 10           Hold Your Breath (Search and Rescue #1)    One  28.82
# 11                               Dirty (Dive Bar #1)   Four  40.83
# 12       Take Me Home Tonight (Rock Star Romance #3)  Three  53.98
# ...

# %%
result_concat = pd.concat([df, df1, df2, df3, df4, df5, df6, df7, df8, df9], ignore_index=True)
result_concat
# Out:
#                                                  Judul Rating  Harga
# 0                                    The Secret Garden   Four  15.08
# 1                                    The Metamorphosis    One  28.58
# 2                               The Pilgrim's Progress    Two  50.26
# 3    The Hound of the Baskervilles (Sherlock Holmes...    Two  14.82
# 4                       Little Women (Little Women #1)   Four  28.07
# ..                                                 ...    ...    ...
# 130                                    Sit, Stay, Love  Three  20.90
# 131    A Girl's Guide to Moving On (New Beginnings #2)    One  31.30
# 132                 The Perfect Play (Play by Play #1)  Three  59.99
# 133           Dark Lover (Black Dagger Brotherhood #1)    One  12.87
# 134                Changing the Game (Play by Play #2)  Three  13.38
#
# [135 rows x 3 columns]

# %%
result_concat['Rating'].replace({'Five': '5', 'Four': '4', 'Three' : '3', 'Two' : '2', 'One' : '1'}, inplace=True)
result_concat
# Out:
#                                                  Judul Rating  Harga
# 0                                    The Secret Garden      4  15.08
# 1                                    The Metamorphosis      1  28.58
# 2                               The Pilgrim's Progress      2  50.26
# 3    The Hound of the Baskervilles (Sherlock Holmes...      2  14.82
# 4                       Little Women (Little Women #1)      4  28.07
# ..                                                 ...    ...    ...
# 130                                    Sit, Stay, Love      3  20.90
# 131    A Girl's Guide to Moving On (New Beginnings #2)      1  31.30
# 132                 The Perfect Play (Play by Play #1)      3  59.99
# 133           Dark Lover (Black Dagger Brotherhood #1)      1  12.87
# 134                Changing the Game (Play by Play #2)      3  13.38
#
# [135 rows x 3 columns]

# %%
def category (Rating):
    if Rating == '5' :
        return 'uapik'
    elif Rating == '4' :
        return 'oke'
    elif Rating == '3' :
        return 'ya'
    elif Rating == '2' :
        return 'y'
    else:
        return 'o'
    
result_concat['Review']=result_concat['Rating'].apply(category)
result_concat
# Out:
#                                                  Judul Rating  Harga Review
# 0                                    The Secret Garden      4  15.08    oke
# 1                                    The Metamorphosis      1  28.58      o
# 2                               The Pilgrim's Progress      2  50.26      y
# 3    The Hound of the Baskervilles (Sherlock Holmes...      2  14.82      y
# 4                       Little Women (Little Women #1)      4  28.07    oke
# ..                                                 ...    ...    ...    ...
# 130                                    Sit, Stay, Love      3  20.90     ya
# 131    A Girl's Guide to Moving On (New Beginnings #2)      1  31.30      o
# 132                 The Perfect Play (Play by Play #1)      3  59.99     ya
# 133           Dark Lover (Black Dagger Brotherhood #1)      1  12.87      o
# 134                Changing the Game (Play by Play #2)      3  13.38     ya
#
# [135 rows x 4 columns]

# %%
result_concat['Harga'].max()
# Out:
# 59.99

# %%
result_concat['Harga'].min()
# Out:
# 10.56

# %% [markdown]
# euro ke rupiah
# harga mahal dan murah

# %% [markdown]
# for book in soup.find_all('h3'):
#             title = book.a.attrs['title']
#             price = article.find('p', class_='price_color').text
#             price = float(price[1:])
#             data.append([title,price])

# %%
import requests
from bs4 import BeautifulSoup

def scrape_page(url):
    response = requests.get(url)
    #if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
        # Proses ekstraksi data dari halaman
    data = []
    for article in articles:
        image = article.find('img')
        title = image.attrs['alt']
        starTag = article.find('p')
        star = starTag['class'][1]
        price = article.find('p', class_='price_color').text
        price = float(price[1:])
        data.append([title, star, price])
        return data
    else:
        print(f"Failed to fetch page: {url}")
        return None

def scrape_multiple_pages(base_url, num_pages):
    all_data = []
    for page_num in range(1, num_pages + 1):
        url = f"{base_url}/page-{page_num}.html"
        data = scrape_page(url)
        if data:
            all_data.extend(data)
    return all_data

base_url = "http://books.toscrape.com/catalogue/category/books/fantasy_19"
num_pages_to_scrape = 3

result = scrape_multiple_pages(base_url, num_pages_to_scrape)
#for title in result:
    #print(title)
df10 = pd.DataFrame(result,columns=['Judul', 'Rating', 'Harga'])
#df10 = df10.set_index('Genre Fantasy')
df10
# Out:
#                         Judul Rating  Harga
# 0  Chase Me (Paris Nights #2)   Five  25.27
# 1  Chase Me (Paris Nights #2)   Five  25.27
# 2  Chase Me (Paris Nights #2)   Five  25.27

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Judul   3 non-null      object
#  1   Rating  3 non-null      object
#  2   Harga   3 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df10.describe()
# Out:
#        Harga
# count   3.00
# mean   25.27
# std     0.00
# min    25.27
# 25%    25.27
# 50%    25.27
# 75%    25.27
# max    25.27

# %%
import requests
from bs4 import BeautifulSoup

def scrape_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        # Proses ekstraksi data dari halaman
        data = []
        for article in articles:
            image = article.find('img')
            title = image.attrs['alt']
            starTag = article.find('p')
            star = starTag['class'][1]
            price = article.find('p', class_='price_color').text
            #price = float(price[1:])
            data.append([title, star, price])
            
        return data
    else:
        print(f"Failed to fetch page: {url}")
        return None

def scrape_multiple_pages(base_url, num_pages):
    all_data = []
    for page_num in range(1, num_pages + 1):
        url = f"{base_url}/page-{page_num}.html"
        data = scrape_page(url)
        if data:
            all_data.extend(data)
    return all_data

base_url = "http://books.toscrape.com/catalogue/category/books/fantasy_19/page-1.html"
num_pages_to_scrape = 3

result = scrape_multiple_pages(base_url, num_pages_to_scrape)
for title in result:
    print(title)
#df11 = pd.DataFrame(result,columns=['Judul', 'Rating', 'Harga'])
#df10 = df10.set_index('Genre Fantasy')
#df11
# Out:
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books/fantasy_19/page-1.html/page-1.html
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books/fantasy_19/page-1.html/page-2.html
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books/fantasy_19/page-1.html/page-3.html

# %%
import requests
from bs4 import BeautifulSoup

def scrape_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        # Proses ekstraksi data dari halaman
        data = []
        for article in articles:
            image = article.find('img')
            title = image.attrs['alt']
            starTag = article.find('p')
            star = starTag['class'][1]
            price = article.find('p', class_='price_color').text
            price = float(price[1:])
            data.append([title, star, price])
            return data
        
    else:
        print(f"Failed to fetch page: {url}")
        return None

def scrape_multiple_pages(base_url, num_pages):
    all_data = []
    for page_num in range(1, num_pages + 1):
        url = f"{base_url}/page-{page_num}.html"
        data = scrape_page(url)
        if data:
            all_data.extend(data)
    return all_data

base_url = "http://books.toscrape.com/catalogue/category/books_1/index.html"
num_pages_to_scrape = 50

result = scrape_multiple_pages(base_url, num_pages_to_scrape)
df10 = pd.DataFrame(result,columns=['Judul', 'Rating', 'Harga'])
df10
# Out:
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books_1/index.html/page-1.html
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books_1/index.html/page-2.html
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books_1/index.html/page-3.html
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books_1/index.html/page-4.html
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books_1/index.html/page-5.html
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books_1/index.html/page-6.html
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books_1/index.html/page-7.html
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books_1/index.html/page-8.html
# Failed to fetch page: http://books.toscrape.com/catalogue/category/books_1/index.html/page-9.html
# ...

# %%
import requests
from bs4 import BeautifulSoup

def scrape_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        # Proses ekstraksi data dari halaman
        data = []
        for article in articles:
            image = article.find('img')
            title = image.attrs['alt']
            starTag = article.find('p')
            star = starTag['class'][1]
            price = article.find('p', class_='price_color').text
            #price = float(price[1:])
            data.append([title, star, price])
            
        return data
    else:
        print(f"Failed to fetch page: {url}")
        return None

def scrape_multiple_pages(base_url, num_pages):
    all_data = []
    for page_num in range(1, num_pages + 1):
        url = f"{base_url}/page-{page_num}.html"
        data = scrape_page(url)
        if data:
            all_data.extend(data)
    return all_data

base_url = "http://books.toscrape.com/catalogue/category/books/fantasy_19"
num_pages_to_scrape = 3

result = scrape_multiple_pages(base_url, num_pages_to_scrape)
#for title in result:
    #print(title)
df10 = pd.DataFrame(result,columns=['Judul', 'Rating', 'Harga'])
#df10 = df10.set_index('Genre Fantasy')
df10
# Out:
#                                                Judul Rating   Harga
# 0                         Chase Me (Paris Nights #2)   Five  £25.27
# 1                                         Black Dust   Five  £34.53
# 2      Her Backup Boyfriend (The Sorensen Family #1)    One  £33.97
# 3                 First and First (Five Boroughs #3)   Four  £15.97
# 4              Fifty Shades Darker (Fifty Shades #2)    One  £21.96
# 5                                  The Wedding Dress    One  £24.12
# 6                   Suddenly in Love (Lake Haven #1)    Two  £55.99
# 7                           Something More Than This   Four  £16.24
# 8                  Doing It Over (Most Likely To #1)  Three  £35.61
# 9                The Wedding Pact (The O'Malleys #2)  Three  £32.61
# 10           Hold Your Breath (Search and Rescue #1)    One  £28.82
# 11                               Dirty (Dive Bar #1)   Four  £40.83
# 12       Take Me Home Tonight (Rock Star Romance #3)  Three  £53.98
# ...
